# %% [markdown]
# # DigitizePID Dataset Generator
#
# **Input structure** (Classes folder with symbol categories):
# ```
# Classes/
# ├── Pumps/
# ├── Instruments/
# ├── Motors/
# ├── Valves/
# └── ...
# ```
#
# **Output structure** (Images + CRAFT ICDAR Annotations):
# ```
# Output/
# ├── Images/
# │   ├── 0.png, 1.png, 2.png, ...
# └── Annotations/
#     ├── gt_0.txt, gt_1.txt, gt_2.txt, ...
# ```

# %%
# Configure parameters - use absolute paths
output_dir = r"C:\Users\91838\Desktop\DigitizePID_Dataset\Output"
symbols_dir = r"C:\Users\91838\Desktop\DigitizePID_Dataset\Classes"
num_images = 20

# %%
# %run Scripts/generate_digitizepid_augmented.py --output_dir $output_dir --symbols_dir $symbols_dir --num_images $num_images
# Out:
# DigitizePID augmented: 20 images, canvas 7168x4561, Output only (no ImagesInfo/.npy)
#   generated 1/20
#   generated 5/20
#   generated 10/20
#   generated 15/20
#   generated 20/20
# Done. Images: C:\Users\91838\Desktop\DigitizePID_Dataset\Output\Images, Annotations: C:\Users\91838\Desktop\DigitizePID_Dataset\Output\Annotations
